# %% [markdown]
# <a href="https://colab.research.google.com/github/ka5hely/MSSP-6070-Practical-Programming/blob/main/Modules/Week_04/Week_04_Data_Aggregation_and_Group_Operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Aggregation and Group Operations

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import userdata
import os

github_token = userdata.get('GitHub')
owner = 'ka5hely' # Replace with the GitHub repository owner
repository = 'MSSP-6070-Practical-Programming' # Replace with the GitHub repository name

clone_url = f'https://{github_token}@github.com/{owner}/{repository}.git'

# Clone the repository
# !git clone {clone_url}

# Navigate into the cloned repository directory (optional, but often useful)
os.chdir(repository)
print(f"Changed directory to: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# fatal: destination path 'MSSP-6070-Practical-Programming' already exists and is not an empty directory.
# Changed directory to: /content/drive/My Drive/MSSP_607/WeeklyModules/Week_4/MSSP-6070-Practical-Programming/MSSP-6070-Practical-Programming

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %%
#%pushd is a Jupyter magic command that opens a file location for processing.
#In Python SEE https://docs.python.org/3/library/functions.html#open, or
#https://docs.python.org/3/library/csv.html?highlight=read
#In Pandas we will use the pandas.read_csv, pandas.read_excel, etc. methods to read files.

# %pushd "/content/drive/MyDrive/MSSP_607/WeeklyModules/Week_4"
# Out:
# /content/drive/MyDrive/MSSP_607/WeeklyModules/Week_4
# ['/content/drive/My Drive/MSSP_607/WeeklyModules/Week_4/MSSP-6070-Practical-Programming/MSSP-6070-Practical-Programming',
#  '/content/drive/My Drive/MSSP_607/WeeklyModules/Week_4/MSSP-6070-Practical-Programming',
#  '/content/drive/My Drive/MSSP_607/WeeklyModules/Week_4/MSSP-6070-Practical-Programming',
#  '/content/MSSP-6070-Practical-Programming/MSSP-6070-Practical-Programming']

# %% [markdown]
# ## GroupBy Mechanics

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.204708  1.393406
# 1    a  two  0.478943  0.092908
# 2    b  one -0.519439  0.281746
# 3    b  two -0.555730  0.769023
# 4    a  one  1.965781  1.246435

# %%
grouped = df['data1'].groupby(df['key1'])
grouped

# %%
grouped.mean()
# Out:
# key1
# a    0.746672
# b   -0.537585
# Name: data1, dtype: float64

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()
means
# Out:
# key1  key2
# a     one     0.880536
#       two     0.478943
# b     one    -0.519439
#       two    -0.555730
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2       one       two
# key1
# a     0.880536  0.478943
# b    -0.519439 -0.555730

# %%
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])
years = np.array([2005, 2005, 2006, 2005, 2006])
df['data1'].groupby([states, years]).mean()
# Out:
# California  2005    0.478943
#             2006   -0.519439
# Ohio        2005   -0.380219
#             2006    1.965781
# Name: data1, dtype: float64

# %%
#df.groupby('key1').mean()
df.groupby(['key1', 'key2']).mean()
# Out:
#               data1     data2
# key1 key2
# a    one   0.880536  1.319920
#      two   0.478943  0.092908
# b    one  -0.519439  0.281746
#      two  -0.555730  0.769023

# %%
df.groupby(level=-1).mean(numeric_only=True)
df.groupby(by=['key1', 'key2']).mean(numeric_only=True)
# Out:
#               data1     data2
# key1 key2
# a    one   0.880536  1.319920
#      two   0.478943  0.092908
# b    one  -0.519439  0.281746
#      two  -0.555730  0.769023

# %%
df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %% [markdown]
# ### Iterating Over Groups

# %%
for name, group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one -0.204708  1.393406
# 1    a  two  0.478943  0.092908
# 4    a  one  1.965781  1.246435
# b
#   key1 key2     data1     data2
# 2    b  one -0.519439  0.281746
# 3    b  two -0.555730  0.769023

# %%
for (k1,k2), group in df.groupby(['key1', 'key2']):
    print((k1,k2))
    print(group)
# Out:
# ('a', 'one')
#   key1 key2     data1     data2
# 0    a  one -0.204708  1.393406
# 4    a  one  1.965781  1.246435
# ('a', 'two')
#   key1 key2     data1     data2
# 1    a  two  0.478943  0.092908
# ('b', 'one')
#   key1 key2     data1     data2
# 2    b  one -0.519439  0.281746
# ('b', 'two')
#   key1 key2    data1     data2
# 3    b  two -0.55573  0.769023

# %%
pieces = dict(list(df.groupby('key1')))
pieces['b']
# Out:
#   key1 key2     data1     data2
# 2    b  one -0.519439  0.281746
# 3    b  two -0.555730  0.769023

# %%
test = df.groupby('key1')
test

# %%
pieces
# Out:
# {'a':   key1 key2     data1     data2
#  0    a  one -0.204708  1.393406
#  1    a  two  0.478943  0.092908
#  4    a  one  1.965781  1.246435,
#  'b':   key1 key2     data1     data2
#  2    b  one -0.519439  0.281746
#  3    b  two -0.555730  0.769023}

# %%
df.dtypes
grouped = df.groupby(df.dtypes, axis=1)
# Out:
# /tmp/ipykernel_1179/323183896.py:2: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   grouped = df.groupby(df.dtypes, axis=1)

# %%
for dtype, group in grouped:
    print(dtype)
    print(group)
# Out:
# float64
#       data1     data2
# 0 -0.204708  1.393406
# 1  0.478943  0.092908
# 2 -0.519439  0.281746
# 3 -0.555730  0.769023
# 4  1.965781  1.246435
# object
#   key1 key2
# 0    a  one
# 1    a  two
# 2    b  one
# 3    b  two
# 4    a  one

# %% [markdown]
# ### Selecting a Column or Subset of Columns

# %% [markdown]
# df.groupby('key1')['data1']
# df.groupby('key1')[['data2']]

# %% [markdown]
# df['data1'].groupby(df['key1'])
# df[['data2']].groupby(df['key1'])

# %%
df.groupby(['key1', 'key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    one   1.319920
#      two   0.092908
# b    one   0.281746
#      two   0.769023

# %%
s_grouped = df.groupby(['key1', 'key2'])['data2']
s_grouped

# %% [markdown]
# ### Grouping with Dicts and Series

# %%
people = pd.DataFrame(np.random.randn(5, 5),
                      columns=['a', 'b', 'c', 'd', 'e'],
                      index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])
people.iloc[2:3, [1, 2]] = np.nan # Add a few NA values
people
# Out:
#                a         b         c         d         e
# Joe     1.007189 -1.296221  0.274992  0.228913  1.352917
# Steve   0.886429 -2.001637 -0.371843  1.669025 -0.438570
# Wes    -0.539741       NaN       NaN -1.021228 -0.577087
# Jim     0.124121  0.302614  0.523772  0.000940  1.343810
# Travis -0.713544 -0.831154 -2.370232 -1.860761 -0.860757

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue',
           'd': 'blue', 'e': 'red', 'f' : 'orange'}

# %%
by_column = people.groupby(mapping, axis=1)
by_column.sum()
# Out:
# /tmp/ipykernel_1179/2922953290.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   by_column = people.groupby(mapping, axis=1)
#             blue       red
# Joe     0.503905  1.063885
# Steve   1.297183 -1.553778
# Wes    -1.021228 -1.116829
# Jim     0.524712  1.770545
# Travis -4.230992 -2.405455

# %%
map_series = pd.Series(mapping)
map_series
people.groupby(map_series, axis=1).count()
# Out:
# /tmp/ipykernel_1179/3950100630.py:3: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   people.groupby(map_series, axis=1).count()
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %% [markdown]
# ### Grouping with Functions

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3  0.591569 -0.993608  0.798764 -0.791374  2.119639
# 5  0.886429 -2.001637 -0.371843  1.669025 -0.438570
# 6 -0.713544 -0.831154 -2.370232 -1.860761 -0.860757

# %%
key_list = ['one', 'one', 'one', 'two', 'two']
people.groupby([len, key_list]).min()
# Out:
#               a         b         c         d         e
# 3 one -0.539741 -1.296221  0.274992 -1.021228 -0.577087
#   two  0.124121  0.302614  0.523772  0.000940  1.343810
# 5 one  0.886429 -2.001637 -0.371843  1.669025 -0.438570
# 6 two -0.713544 -0.831154 -2.370232 -1.860761 -0.860757

# %% [markdown]
# ### Grouping by Index Levels

# %%
columns = pd.MultiIndex.from_arrays([['US', 'US', 'US', 'JP', 'JP'],
                                    [1, 3, 5, 1, 3]],
                                    names=['cty', 'tenor'])
hier_df = pd.DataFrame(np.random.randn(4, 5), columns=columns)
hier_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0      0.560145 -1.265934  0.119827 -1.063512  0.332883
# 1     -2.359419 -0.199543 -1.541996 -0.970736 -1.307030
# 2      0.286350  0.377984 -0.753887  0.331286  1.349742
# 3      0.069877  0.246674 -0.011862  1.004812  1.327195

# %%
hier_df.groupby(level='cty', axis=1).count()
# Out:
# /tmp/ipykernel_1179/2333815484.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   hier_df.groupby(level='cty', axis=1).count()
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %% [markdown]
# ## Data Aggregation

# %%
df
grouped = df.groupby('key1')
grouped['data1'].quantile(0.9)
# Out:
# key1
# a    1.668413
# b   -0.523068
# Name: data1, dtype: float64

# %%
data = {'A': [1, 2, 1, 2], 'B': [10, 20, 30, 40]}
df = pd.DataFrame(data)
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  1  30
# 3  2  40

# %%
df.agg('sum')
# Out:
# A      6
# B    100
# dtype: int64

# %%
def peak_to_peak(arr):
    return arr.max() - arr.min()

df.agg(peak_to_peak)
# Out:
# A     1
# B    30
# dtype: int64

# %%
df.describe()
# Out:
#              A          B
# count  4.00000   4.000000
# mean   1.50000  25.000000
# std    0.57735  12.909944
# min    1.00000  10.000000
# 25%    1.00000  17.500000
# 50%    1.50000  25.000000
# 75%    2.00000  32.500000
# max    2.00000  40.000000

# %% [markdown]
# ### Column-Wise and Multiple Function Application

# %%
tips = pd.read_csv('/content/drive/MyDrive/MSSP_607/WeeklyModules/Week_4/tips.csv')
# Add tip percentage of total bill
tips['tip_pct'] = tips['tip'] / tips['total_bill']
tips[:6]
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61     No  Sun  Dinner     4  0.146808
# 5       25.29  4.71     No  Sun  Dinner     4  0.186240

# %%
grouped = tips.groupby(['day', 'smoker'])

# %%
grouped_pct = grouped['tip_pct']
grouped_pct.agg('mean')
# Out:
# day   smoker
# Fri   No        0.151650
#       Yes       0.174783
# Sat   No        0.158048
#       Yes       0.147906
# Sun   No        0.160113
#       Yes       0.187250
# Thur  No        0.160298
#       Yes       0.163863
# Name: tip_pct, dtype: float64

# %%
grouped_pct.agg(['mean', 'std', peak_to_peak])
# Out:
#                  mean       std  peak_to_peak
# day  smoker
# Fri  No      0.151650  0.028123      0.067349
#      Yes     0.174783  0.051293      0.159925
# Sat  No      0.158048  0.039767      0.235193
#      Yes     0.147906  0.061375      0.290095
# Sun  No      0.160113  0.042347      0.193226
#      Yes     0.187250  0.154134      0.644685
# Thur No      0.160298  0.038774      0.193350
#      Yes     0.163863  0.039389      0.151240

# %%
grouped_pct.agg([('foo', 'mean'), ('bar', np.std)])
# Out:
# /tmp/ipykernel_1179/345979284.py:1: FutureWarning: The provided callable <function std at 0x7a1bc0b640e0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   grouped_pct.agg([('foo', 'mean'), ('bar', np.std)])
#                   foo       bar
# day  smoker
# Fri  No      0.151650  0.028123
#      Yes     0.174783  0.051293
# Sat  No      0.158048  0.039767
#      Yes     0.147906  0.061375
# Sun  No      0.160113  0.042347
#      Yes     0.187250  0.154134
# Thur No      0.160298  0.038774
#      Yes     0.163863  0.039389

# %%
functions = ['count', 'mean', 'max']
result = grouped[['tip_pct', 'total_bill']].agg(functions)
result
# Out:
#             tip_pct                     total_bill
#               count      mean       max      count       mean    max
# day  smoker
# Fri  No           4  0.151650  0.187735          4  18.420000  22.75
#      Yes         15  0.174783  0.263480         15  16.813333  40.17
# Sat  No          45  0.158048  0.291990         45  19.661778  48.33
#      Yes         42  0.147906  0.325733         42  21.276667  50.81
# Sun  No          57  0.160113  0.252672         57  20.506667  48.17
#      Yes         19  0.187250  0.710345         19  24.120000  45.35
# Thur No          45  0.160298  0.266312         45  17.113111  41.19
#      Yes         17  0.163863  0.241255         17  19.190588  43.11

# %%
result['tip_pct']
# Out:
#              count      mean       max
# day  smoker
# Fri  No          4  0.151650  0.187735
#      Yes        15  0.174783  0.263480
# Sat  No         45  0.158048  0.291990
#      Yes        42  0.147906  0.325733
# Sun  No         57  0.160113  0.252672
#      Yes        19  0.187250  0.710345
# Thur No         45  0.160298  0.266312
#      Yes        17  0.163863  0.241255

# %%
ftuples = [('Durchschnitt', 'mean'), ('Abweichung', np.var)]
grouped[['tip_pct', 'total_bill']].agg(ftuples)
# Out:
# /tmp/ipykernel_1179/3693139596.py:2: FutureWarning: The provided callable <function var at 0x7a1bc0b64220> is currently using SeriesGroupBy.var. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "var" instead.
#   grouped[['tip_pct', 'total_bill']].agg(ftuples)
#                  tip_pct              total_bill
#             Durchschnitt Abweichung Durchschnitt  Abweichung
# day  smoker
# Fri  No         0.151650   0.000791    18.420000   25.596333
#      Yes        0.174783   0.002631    16.813333   82.562438
# Sat  No         0.158048   0.001581    19.661778   79.908965
#      Yes        0.147906   0.003767    21.276667  101.387535
# Sun  No         0.160113   0.001793    20.506667   66.099980
#      Yes        0.187250   0.023757    24.120000  109.046044
# Thur No         0.160298   0.001503    17.113111   59.625081
#      Yes        0.163863   0.001551    19.190588   69.808518

# %%
grouped.agg({'tip' : np.max, 'size' : 'sum'})
grouped.agg({'tip_pct' : ['min', 'max', 'mean', 'std'],
             'size' : 'sum'})
# Out:
# /tmp/ipykernel_1179/3863922381.py:1: FutureWarning: The provided callable <function max at 0x7a1bc0b57560> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped.agg({'tip' : np.max, 'size' : 'sum'})
#               tip_pct                               size
#                   min       max      mean       std  sum
# day  smoker
# Fri  No      0.120385  0.187735  0.151650  0.028123    9
#      Yes     0.103555  0.263480  0.174783  0.051293   31
# Sat  No      0.056797  0.291990  0.158048  0.039767  115
#      Yes     0.035638  0.325733  0.147906  0.061375  104
# Sun  No      0.059447  0.252672  0.160113  0.042347  167
#      Yes     0.065660  0.710345  0.187250  0.154134   49
# Thur No      0.072961  0.266312  0.160298  0.038774  112
#      Yes     0.090014  0.241255  0.163863  0.039389   40

# %% [markdown]
# ### Returning Aggregated Data Without Row Indexes

# %%
tips.groupby(['day', 'smoker'])[['total_bill']].mean()
# Out:
#              total_bill
# day  smoker
# Fri  No       18.420000
#      Yes      16.813333
# Sat  No       19.661778
#      Yes      21.276667
# Sun  No       20.506667
#      Yes      24.120000
# Thur No       17.113111
#      Yes      19.190588

# %% [markdown]
# ## Apply: General split-apply-combine

# %%
def top(df, n=5, column='tip_pct'):
    return df.sort_values(by=column)[-n:]
top(tips, n=6)
# Out:
#      total_bill   tip smoker  day    time  size   tip_pct
# 109       14.31  4.00    Yes  Sat  Dinner     2  0.279525
# 183       23.17  6.50    Yes  Sun  Dinner     4  0.280535
# 232       11.61  3.39     No  Sat  Dinner     2  0.291990
# 67         3.07  1.00    Yes  Sat  Dinner     1  0.325733
# 178        9.60  4.00    Yes  Sun  Dinner     2  0.416667
# 172        7.25  5.15    Yes  Sun  Dinner     2  0.710345

# %%
tips.groupby('smoker').apply(top)
# Out:
# /tmp/ipykernel_1179/1695234324.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tips.groupby('smoker').apply(top)
#             total_bill   tip smoker   day    time  size   tip_pct
# smoker
# No     88        24.71  5.85     No  Thur   Lunch     2  0.236746
#        185       20.69  5.00     No   Sun  Dinner     5  0.241663
#        51        10.29  2.60     No   Sun  Dinner     2  0.252672
#        149        7.51  2.00     No  Thur   Lunch     2  0.266312
#        232       11.61  3.39     No   Sat  Dinner     2  0.291990
# Yes    109       14.31  4.00    Yes   Sat  Dinner     2  0.279525
#        183       23.17  6.50    Yes   Sun  Dinner     4  0.280535
# ...

# %%
tips.groupby(['smoker', 'day']).apply(top, n=1, column='total_bill')
# Out:
# /tmp/ipykernel_1179/4096842605.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tips.groupby(['smoker', 'day']).apply(top, n=1, column='total_bill')
#                  total_bill    tip smoker   day    time  size   tip_pct
# smoker day
# No     Fri  94        22.75   3.25     No   Fri  Dinner     2  0.142857
#        Sat  212       48.33   9.00     No   Sat  Dinner     4  0.186220
#        Sun  156       48.17   5.00     No   Sun  Dinner     6  0.103799
#        Thur 142       41.19   5.00     No  Thur   Lunch     5  0.121389
# Yes    Fri  95        40.17   4.73    Yes   Fri  Dinner     4  0.117750
#        Sat  170       50.81  10.00    Yes   Sat  Dinner     3  0.196812
# ...

# %%
result = tips.groupby('smoker')['tip_pct'].describe()
result
result.unstack('smoker')
# Out:
#        smoker
# count  No        151.000000
#        Yes        93.000000
# mean   No          0.159328
#        Yes         0.163196
# std    No          0.039910
#        Yes         0.085119
# min    No          0.056797
#        Yes         0.035638
# 25%    No          0.136906
#        Yes         0.106771
# 50%    No          0.155625
#        Yes         0.153846
# 75%    No          0.185014
#        Yes         0.195059
# max    No          0.291990
#        Yes         0.710345
# dtype: float64

# %%
f = lambda x: x.describe()
grouped.apply(f)
# Out:
# /tmp/ipykernel_1179/2978092441.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped.apply(f)
#                    total_bill       tip  size   tip_pct
# day  smoker
# Fri  No     count    4.000000  4.000000  4.00  4.000000
#             mean    18.420000  2.812500  2.25  0.151650
#             std      5.059282  0.898494  0.50  0.028123
#             min     12.460000  1.500000  2.00  0.120385
#             25%     15.100000  2.625000  2.00  0.137239
# ...                       ...       ...   ...       ...
# Thur Yes    min     10.340000  2.000000  2.00  0.090014
#             25%     13.510000  2.000000  2.00  0.148038
#             50%     16.470000  2.560000  2.00  0.153846
# ...

# %% [markdown]
# ### Suppressing the Group Keys

# %%
tips.groupby('smoker', group_keys=False).apply(top)
# Out:
# /tmp/ipykernel_1179/1502793219.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tips.groupby('smoker', group_keys=False).apply(top)
#      total_bill   tip smoker   day    time  size   tip_pct
# 88        24.71  5.85     No  Thur   Lunch     2  0.236746
# 185       20.69  5.00     No   Sun  Dinner     5  0.241663
# 51        10.29  2.60     No   Sun  Dinner     2  0.252672
# 149        7.51  2.00     No  Thur   Lunch     2  0.266312
# 232       11.61  3.39     No   Sat  Dinner     2  0.291990
# 109       14.31  4.00    Yes   Sat  Dinner     2  0.279525
# 183       23.17  6.50    Yes   Sun  Dinner     4  0.280535
# 67         3.07  1.00    Yes   Sat  Dinner     1  0.325733
# ...

# %% [markdown]
# ### Quantile and Bucket Analysis

# %%
frame = pd.DataFrame({'data1': np.random.randn(1000),
                      'data2': np.random.randn(1000)})
quartiles = pd.cut(frame.data1, 4)
quartiles[:10]
# Out:
# 0     (-1.23, 0.489]
# 1    (-2.956, -1.23]
# 2     (-1.23, 0.489]
# 3     (0.489, 2.208]
# 4     (-1.23, 0.489]
# 5     (0.489, 2.208]
# 6     (-1.23, 0.489]
# 7     (-1.23, 0.489]
# 8     (0.489, 2.208]
# 9     (0.489, 2.208]
# Name: data1, dtype: category
# Categories (4, interval[float64, right]): [(-2.956, -1.23] < (-1.23, 0.489] < (0.489, 2.208] <
#                                            (2.208, 3.928]]

# %%
def get_stats(group):
    return {'min': group.min(), 'max': group.max(),
            'count': group.count(), 'mean': group.mean()}
grouped = frame.data2.groupby(quartiles)
grouped.apply(get_stats).unstack()
# Out:
# /tmp/ipykernel_1179/1519350116.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = frame.data2.groupby(quartiles)
#                       min       max  count      mean
# data1
# (-2.956, -1.23] -3.399312  1.670835   95.0 -0.039521
# (-1.23, 0.489]  -2.989741  3.260383  598.0 -0.002051
# (0.489, 2.208]  -3.745356  2.954439  297.0  0.081822
# (2.208, 3.928]  -1.929776  1.765640   10.0  0.024750

# %%
# Return quantile numbers
grouping = pd.qcut(frame.data1, 10, labels=False)
grouped = frame.data2.groupby(grouping)
grouped.apply(get_stats).unstack()
# Out:
#             min       max  count      mean
# data1
# 0     -3.399312  1.670835  100.0 -0.049902
# 1     -1.950098  2.628441  100.0  0.030989
# 2     -2.925113  2.527939  100.0 -0.067179
# 3     -2.315555  3.260383  100.0  0.065713
# 4     -2.047939  2.074345  100.0 -0.111653
# 5     -2.989741  2.184810  100.0  0.052130
# 6     -2.223506  2.458842  100.0 -0.021489
# 7     -3.056990  2.954439  100.0 -0.026459
# 8     -3.745356  2.735527  100.0  0.103406
# 9     -2.064111  2.377020  100.0  0.220122

# %% [markdown]
# ### Example: Filling Missing Values with Group-Specific       Values

# %%
s = pd.Series(np.random.randn(6))
s[::2] = np.nan
s
s.fillna(s.mean())
# Out:
# 0   -0.261035
# 1   -0.125921
# 2   -0.261035
# 3   -0.884475
# 4   -0.261035
# 5    0.227290
# dtype: float64

# %%
states = ['Ohio', 'New York', 'Vermont', 'Florida',
          'Oregon', 'Nevada', 'California', 'Idaho']
group_key = ['East'] * 4 + ['West'] * 4
data = pd.Series(np.random.randn(8), index=states)
data
# Out:
# Ohio          0.922264
# New York     -2.153545
# Vermont      -0.365757
# Florida      -0.375842
# Oregon        0.329939
# Nevada        0.981994
# California    1.105913
# Idaho        -1.613716
# dtype: float64

# %%
data[['Vermont', 'Nevada', 'Idaho']] = np.nan
data
data.groupby(group_key).mean()
# Out:
# East   -0.535707
# West    0.717926
# dtype: float64

# %%
fill_mean = lambda g: g.fillna(g.mean())
data.groupby(group_key).apply(fill_mean)
# Out:
# East  Ohio          0.922264
#       New York     -2.153545
#       Vermont      -0.535707
#       Florida      -0.375842
# West  Oregon        0.329939
#       Nevada        0.717926
#       California    1.105913
#       Idaho         0.717926
# dtype: float64

# %%
fill_values = {'East': 0.5, 'West': -1}
fill_func = lambda g: g.fillna(fill_values[g.name])
data.groupby(group_key).apply(fill_func)
# Out:
# East  Ohio          0.922264
#       New York     -2.153545
#       Vermont       0.500000
#       Florida      -0.375842
# West  Oregon        0.329939
#       Nevada       -1.000000
#       California    1.105913
#       Idaho        -1.000000
# dtype: float64

# %% [markdown]
# ### Example: Random Sampling and Permutation

# %%
# Hearts, Spades, Clubs, Diamonds
suits = ['H', 'S', 'C', 'D']
card_val = (list(range(1, 11)) + [10] * 3) * 4
base_names = ['A'] + list(range(2, 11)) + ['J', 'K', 'Q']
cards = []
for suit in ['H', 'S', 'C', 'D']:
    cards.extend(str(num) + suit for num in base_names)

deck = pd.Series(card_val, index=cards)

# %%
deck[:13]
# Out:
# AH      1
# 2H      2
# 3H      3
# 4H      4
# 5H      5
# 6H      6
# 7H      7
# 8H      8
# 9H      9
# 10H    10
# JH     10
# KH     10
# QH     10
# dtype: int64

# %%
def draw(deck, n=5):
    return deck.sample(n)
draw(deck)
# Out:
# AD     1
# 8C     8
# 5H     5
# KC    10
# 2C     2
# dtype: int64

# %%
get_suit = lambda card: card[-1] # last letter is suit
deck.groupby(get_suit).apply(draw, n=2)
# Out:
# C  2C     2
#    3C     3
# D  KD    10
#    8D     8
# H  KH    10
#    3H     3
# S  2S     2
#    4S     4
# dtype: int64

# %%
deck.groupby(get_suit, group_keys=False).apply(draw, n=2)
# Out:
# KC    10
# JC    10
# AD     1
# 5D     5
# 5H     5
# 6H     6
# 7S     7
# KS    10
# dtype: int64

# %% [markdown]
# ### Example: Group Weighted Average and Correlation

# %%
df = pd.DataFrame({'category': ['a', 'a', 'a', 'a',
                                'b', 'b', 'b', 'b'],
                   'data': np.random.randn(8),
                   'weights': np.random.rand(8)})
df
# Out:
#   category      data   weights
# 0        a  1.561587  0.957515
# 1        a  1.219984  0.347267
# 2        a -0.482239  0.581362
# 3        a  0.315667  0.217091
# 4        b -0.047852  0.894406
# 5        b -0.454145  0.918564
# 6        b -0.556774  0.277825
# 7        b  0.253321  0.955905

# %%
grouped = df.groupby('category')
get_wavg = lambda g: np.average(g['data'], weights=g['weights'])
grouped.apply(get_wavg)
# Out:
# /tmp/ipykernel_1179/2332201017.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped.apply(get_wavg)
# category
# a    0.811643
# b   -0.122262
# dtype: float64

# %%
close_px = pd.read_csv('/content/drive/MyDrive/MSSP_607/WeeklyModules/Week_4/stock_px_2.csv', parse_dates=True,
                       index_col=0)
close_px.info()
close_px[-4:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2214 entries, 2003-01-02 to 2011-10-14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2214 non-null   float64
#  1   MSFT    2214 non-null   float64
#  2   XOM     2214 non-null   float64
#  3   SPX     2214 non-null   float64
# dtypes: float64(4)
# memory usage: 86.5 KB
#               AAPL   MSFT    XOM      SPX
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58

# %%
spx_corr = lambda x: x.corrwith(x['SPX'])

# %%
rets = close_px.pct_change().dropna()
rets
# Out:
#                 AAPL      MSFT       XOM       SPX
# 2003-01-03  0.006757  0.001421  0.000684 -0.000484
# 2003-01-06  0.000000  0.017975  0.024624  0.022474
# 2003-01-07 -0.002685  0.019052 -0.033712 -0.006545
# 2003-01-08 -0.020188 -0.028272 -0.004145 -0.014086
# 2003-01-09  0.008242  0.029094  0.021159  0.019386
# ...              ...       ...       ...       ...
# 2011-10-10  0.051406  0.026286  0.036977  0.034125
# 2011-10-11  0.029526  0.002227 -0.000131  0.000544
# 2011-10-12  0.004747 -0.001481  0.011669  0.009795
# 2011-10-13  0.015515  0.008160 -0.010238 -0.002974
# 2011-10-14  0.033225  0.003311  0.022784  0.017380
#
# [2213 rows x 4 columns]

# %%
get_year = lambda x: x.year
by_year = rets.groupby(get_year)
by_year.apply(spx_corr)
# Out:
#           AAPL      MSFT       XOM  SPX
# 2003  0.541124  0.745174  0.661265  1.0
# 2004  0.374283  0.588531  0.557742  1.0
# 2005  0.467540  0.562374  0.631010  1.0
# 2006  0.428267  0.406126  0.518514  1.0
# 2007  0.508118  0.658770  0.786264  1.0
# 2008  0.681434  0.804626  0.828303  1.0
# 2009  0.707103  0.654902  0.797921  1.0
# 2010  0.710105  0.730118  0.839057  1.0
# 2011  0.691931  0.800996  0.859975  1.0

# %%
by_year.apply(lambda g: g['AAPL'].corr(g['MSFT']))
# Out:
# 2003    0.480868
# 2004    0.259024
# 2005    0.300093
# 2006    0.161735
# 2007    0.417738
# 2008    0.611901
# 2009    0.432738
# 2010    0.571946
# 2011    0.581987
# dtype: float64

# %% [markdown]
# ### Example: Group-Wise Linear Regression

# %%
import statsmodels.api as sm
def regress(data, yvar, xvars):
    Y = data[yvar]
    X = data[xvars]
    X['intercept'] = 1.
    result = sm.OLS(Y, X).fit()
    return result.params

# %%
by_year.apply(regress, 'AAPL', ['SPX'])
# Out:
#            SPX  intercept
# 2003  1.195406   0.000710
# 2004  1.363463   0.004201
# 2005  1.766415   0.003246
# 2006  1.645496   0.000080
# 2007  1.198761   0.003438
# 2008  0.968016  -0.001110
# 2009  0.879103   0.002954
# 2010  1.052608   0.001261
# 2011  0.806605   0.001514

# %% [markdown]
# ## Pivot Tables and Cross-Tabulation

# %%
## Explicitly specify the numeric columns ('total_bill' and 'tip') you want to aggregate within the values parameter.
tips.pivot_table(index=['day', 'smoker'], values=['total_bill', 'tip'], aggfunc='mean')
# Out:
#                   tip  total_bill
# day  smoker
# Fri  No      2.812500   18.420000
#      Yes     2.714000   16.813333
# Sat  No      3.102889   19.661778
#      Yes     2.875476   21.276667
# Sun  No      3.167895   20.506667
#      Yes     3.516842   24.120000
# Thur No      2.673778   17.113111
#      Yes     3.030000   19.190588

# %%
tips.pivot_table(['tip_pct', 'size'], index=['time', 'day'],
                 columns='smoker')
# Out:
#                  size             tip_pct
# smoker             No       Yes        No       Yes
# time   day
# Dinner Fri   2.000000  2.222222  0.139622  0.165347
#        Sat   2.555556  2.476190  0.158048  0.147906
#        Sun   2.929825  2.578947  0.160113  0.187250
#        Thur  2.000000       NaN  0.159744       NaN
# Lunch  Fri   3.000000  1.833333  0.187735  0.188937
#        Thur  2.500000  2.352941  0.160311  0.163863

# %%
tips.pivot_table(['tip_pct', 'size'], index=['time', 'day'],
                 columns='smoker', margins=True)
# Out:
#                  size                       tip_pct
# smoker             No       Yes       All        No       Yes       All
# time   day
# Dinner Fri   2.000000  2.222222  2.166667  0.139622  0.165347  0.158916
#        Sat   2.555556  2.476190  2.517241  0.158048  0.147906  0.153152
#        Sun   2.929825  2.578947  2.842105  0.160113  0.187250  0.166897
#        Thur  2.000000       NaN  2.000000  0.159744       NaN  0.159744
# Lunch  Fri   3.000000  1.833333  2.000000  0.187735  0.188937  0.188765
#        Thur  2.500000  2.352941  2.459016  0.160311  0.163863  0.161301
# All          2.668874  2.408602  2.569672  0.159328  0.163196  0.160803

# %%
tips.pivot_table('tip_pct', index=['time', 'smoker'], columns='day',
                 aggfunc=len, margins=True)
# Out:
# day             Fri   Sat   Sun  Thur  All
# time   smoker
# Dinner No       3.0  45.0  57.0   1.0  106
#        Yes      9.0  42.0  19.0   NaN   70
# Lunch  No       1.0   NaN   NaN  44.0   45
#        Yes      6.0   NaN   NaN  17.0   23
# All            19.0  87.0  76.0  62.0  244

# %%
tips.pivot_table('tip_pct', index=['time', 'size', 'smoker'],
                 columns='day', aggfunc='mean', fill_value=0)
# Out:
# day                      Fri       Sat       Sun      Thur
# time   size smoker
# Dinner 1    No      0.000000  0.137931  0.000000  0.000000
#             Yes     0.000000  0.325733  0.000000  0.000000
#        2    No      0.139622  0.162705  0.168859  0.159744
#             Yes     0.171297  0.148668  0.207893  0.000000
#        3    No      0.000000  0.154661  0.152663  0.000000
# ...                      ...       ...       ...       ...
# Lunch  3    Yes     0.000000  0.000000  0.000000  0.204952
#        4    No      0.000000  0.000000  0.000000  0.138919
#             Yes     0.000000  0.000000  0.000000  0.155410
#        5    No      0.000000  0.000000  0.000000  0.121389
#        6    No      0.000000  0.000000  0.000000  0.173706
#
# [21 rows x 4 columns]

# %% [markdown]
# ### Cross-Tabulations: Crosstab

# %%
from io import StringIO
data = """\
Sample  Nationality  Handedness
1   USA  Right-handed
2   Japan    Left-handed
3   USA  Right-handed
4   Japan    Right-handed
5   Japan    Left-handed
6   Japan    Right-handed
7   USA  Right-handed
8   USA  Left-handed
9   Japan    Right-handed
10  USA  Right-handed"""
data = pd.read_table(StringIO(data), sep='\s+')
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1179/592307729.py:14: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_table(StringIO(data), sep='\s+')

# %%
data

# %%
pd.crosstab(data.Nationality, data.Handedness, margins=True)

# %%
pd.crosstab([tips.time, tips.day], tips.smoker, margins=True)

# %%
pd.options.display.max_rows = PREVIOUS_MAX_ROWS

# %%
#It is a magic command that is used to remove a directory from the directory stack and
#change the current working directory (cwd) to the previously active directory.
# %popd

# %% [markdown]
# ## Conclusion
